# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')
import yfinance as yf
import datetime
from pandas_datareader import data as pdr

# %%
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

# %%
df = pdr.get_data_yahoo('^NSEI', start_date, end_date)
df.shape
# Out:
# (247, 6)

# %%
df['Date'] = df.index

# %%
df.Date
# Out:
# Date
# 2020-12-23   2020-12-23
# 2020-12-24   2020-12-24
# 2020-12-28   2020-12-28
# 2020-12-29   2020-12-29
# 2020-12-30   2020-12-30
#                 ...
# 2021-12-17   2021-12-17
# 2021-12-20   2021-12-20
# 2021-12-21   2021-12-21
# 2021-12-22   2021-12-22
# 2021-12-23   2021-12-23
# Name: Date, Length: 247, dtype: datetime64[ns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)

# %%
model = model.fit(df, date_col='Date', value_col='Close', id_col=None)
# Out:
# Inferred frequency is: B
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 7: DatepartRegression
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Model Number: 43 with model GLS in generation 0 of 10
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# Model Number: 45 with model GLM in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:293: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# Model Number: 46 with model ETS in generation 0 of 10
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 53: DatepartRegression
# Model Number: 54 with model UnivariateMotif in generation 0 of 10
# Model Number: 55 with model MultivariateMotif in generation 0 of 10
# Model Number: 56 with model SectionalMotif in generation 0 of 10
# Model Number: 57 with model NVAR in generation 0 of 10
# Model Number: 58 with model Theta in generation 0 of 10
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.78617D+00    |proj g|=  4.48834D-01
#
# At iterate    5    f=  2.61875D+00    |proj g|=  1.35181D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      6      1     0     0   1.352D-06   2.619D+00
#   F =   2.6187515189122732
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Model Number: 59 with model ARDL in generation 0 of 10
#  This problem is unconstrained.
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 59: ARDL
# Model Number: 60 with model LastValueNaive in generation 0 of 10
# Model Number: 61 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation maximum which has no identity') in model 61: SectionalMotif
# Model Number: 62 with model Theta in generation 0 of 10
# Model Number: 63 with model NVAR in generation 0 of 10
# Model Number: 64 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 64: FBProphet
# Model Number: 65 with model SeasonalNaive in generation 0 of 10
# Model Number: 66 with model NVAR in generation 0 of 10
# Model Number: 67 with model SectionalMotif in generation 0 of 10
# Model Number: 68 with model MultivariateMotif in generation 0 of 10
# Model Number: 69 with model SectionalMotif in generation 0 of 10
# Model Number: 70 with model ZeroesNaive in generation 0 of 10
# Model Number: 71 with model ETS in generation 0 of 10
# Model Number: 72 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 72: DatepartRegression
# Model Number: 73 with model GLM in generation 0 of 10
# Model Number: 74 with model SeasonalNaive in generation 0 of 10
# Model Number: 75 with model UnobservedComponents in generation 0 of 10
# Model Number: 76 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 76: ARDL
# Model Number: 77 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 77: UnobservedComponents
# Model Number: 78 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 78: ARDL
# Model Number: 79 with model SectionalMotif in generation 0 of 10
# Model Number: 80 with model Theta in generation 0 of 10
# Model Number: 81 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 81: VECM
# Model Number: 82 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 82: VAR
# Model Number: 83 with model SeasonalNaive in generation 0 of 10
# Model Number: 84 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 84: VECM
# Model Number: 85 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 85: SectionalMotif
# Model Number: 86 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 86: UnobservedComponents
# Model Number: 87 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 87: GLM
# Model Number: 88 with model WindowRegression in generation 0 of 10
# Model Number: 89 with model SeasonalNaive in generation 0 of 10
# Template Eval Error: ValueError('Shape of passed values is (190, 191), indices imply (190, 1)') in model 89: SeasonalNaive
# Model Number: 90 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series') in model 90: DatepartRegression
# Model Number: 91 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 91: VECM
# Model Number: 92 with model UnivariateMotif in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1368: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_regression.py:421: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 93 with model LastValueNaive in generation 0 of 10
# Model Number: 94 with model UnivariateMotif in generation 0 of 10
# Model Number: 95 with model SeasonalNaive in generation 0 of 10
# Model Number: 96 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 96: ARDL
# Model Number: 97 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 97: GluonTS
# Model Number: 98 with model MultivariateMotif in generation 0 of 10
# Model Number: 99 with model GLS in generation 0 of 10
# Model Number: 100 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 100: GLM
# Model Number: 101 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 101: ARDL
# Model Number: 102 with model GLM in generation 0 of 10
# Model Number: 103 with model Theta in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/genmod/families/family.py:1231: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:293: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# Model Number: 104 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 104: DatepartRegression
# Model Number: 105 with model SectionalMotif in generation 0 of 10
# Model Number: 106 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 106: VECM
# Model Number: 107 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 107: GLM
# Model Number: 108 with model Theta in generation 0 of 10
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.29284D+00    |proj g|=  1.82904D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      3      1     0     0   4.247D-06   6.293D+00
#   F =   6.2926950140751794
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Model Number: 109 with model GLS in generation 0 of 10
#  This problem is unconstrained.
# Model Number: 110 with model NVAR in generation 0 of 10
# Model Number: 111 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 111: ARDL
# Model Number: 112 with model ZeroesNaive in generation 0 of 10
# Model Number: 113 with model ZeroesNaive in generation 0 of 10
# Model Number: 114 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 114: DatepartRegression
# Model Number: 115 with model UnivariateMotif in generation 0 of 10
# Model Number: 116 with model MultivariateMotif in generation 0 of 10
# Model Number: 117 with model Theta in generation 0 of 10
# Model Number: 118 with model ETS in generation 0 of 10
# Model Number: 119 with model ETS in generation 0 of 10
# Model Number: 120 with model UnivariateMotif in generation 0 of 10
# Model Number: 121 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 121: FBProphet
# Model Number: 122 with model LastValueNaive in generation 0 of 10
# Model Number: 123 with model SectionalMotif in generation 0 of 10
# Model Number: 124 with model GLS in generation 0 of 10
# Model Number: 125 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 125: VAR
# Model Number: 126 with model LastValueNaive in generation 0 of 10
# Model Number: 127 with model ETS in generation 0 of 10
# Model Number: 128 with model Theta in generation 0 of 10
# Model Number: 129 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 129: GluonTS
# Model Number: 130 with model Theta in generation 0 of 10
# Model Number: 131 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 131: FBProphet
# Model Number: 132 with model AverageValueNaive in generation 0 of 10
# Model Number: 133 with model AverageValueNaive in generation 0 of 10
# Model Number: 134 with model LastValueNaive in generation 0 of 10
# Model Number: 135 with model SectionalMotif in generation 0 of 10
# Model Number: 136 with model SeasonalNaive in generation 0 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:470: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# Model Number: 137 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 137: FBProphet
# Model Number: 138 with model ZeroesNaive in generation 0 of 10
# Model Number: 139 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 139: VAR
# New Generation: 1 of 10
# Model Number: 140 with model NVAR in generation 1 of 10
# Model Number: 141 with model NVAR in generation 1 of 10
# Model Number: 142 with model NVAR in generation 1 of 10
# Model Number: 143 with model NVAR in generation 1 of 10
# Model Number: 144 with model SeasonalNaive in generation 1 of 10
# Model Number: 145 with model SeasonalNaive in generation 1 of 10
# Model Number: 146 with model SeasonalNaive in generation 1 of 10
# Model Number: 147 with model SeasonalNaive in generation 1 of 10
# Model Number: 148 with model ETS in generation 1 of 10
# Model Number: 149 with model ETS in generation 1 of 10
# Model Number: 150 with model ETS in generation 1 of 10
# Model Number: 151 with model ETS in generation 1 of 10
# Model Number: 152 with model LastValueNaive in generation 1 of 10
# Model Number: 153 with model LastValueNaive in generation 1 of 10
# Model Number: 154 with model LastValueNaive in generation 1 of 10
# Model Number: 155 with model ZeroesNaive in generation 1 of 10
# Model Number: 156 with model ZeroesNaive in generation 1 of 10
# Model Number: 157 with model ZeroesNaive in generation 1 of 10
# Model Number: 158 with model AverageValueNaive in generation 1 of 10
# Model Number: 159 with model AverageValueNaive in generation 1 of 10
# Model Number: 160 with model AverageValueNaive in generation 1 of 10
# Model Number: 161 with model GLS in generation 1 of 10
# Model Number: 162 with model GLS in generation 1 of 10
# Model Number: 163 with model GLS in generation 1 of 10
# Model Number: 164 with model SectionalMotif in generation 1 of 10
# Model Number: 165 with model SectionalMotif in generation 1 of 10
# Model Number: 166 with model SectionalMotif in generation 1 of 10
# Model Number: 167 with model SectionalMotif in generation 1 of 10
# Model Number: 168 with model UnobservedComponents in generation 1 of 10
# Model Number: 169 with model UnobservedComponents in generation 1 of 10
# Model Number: 170 with model UnobservedComponents in generation 1 of 10
# Model Number: 171 with model WindowRegression in generation 1 of 10
# Model Number: 172 with model WindowRegression in generation 1 of 10
# Model Number: 173 with model WindowRegression in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'lightgbm'") in model 173: WindowRegression
# Model Number: 174 with model Theta in generation 1 of 10
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.00147D+00    |proj g|=  7.60634D-01
#
# At iterate    5    f= -2.00162D+00    |proj g|=  1.21253D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     10      1     0     0   1.213D-05  -2.002D+00
#   F =  -2.0016195022793424
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Model Number: 175 with model Theta in generation 1 of 10
#  This problem is unconstrained.
# Model Number: 176 with model Theta in generation 1 of 10
# Model Number: 177 with model Theta in generation 1 of 10
# Model Number: 178 with model MultivariateMotif in generation 1 of 10
# Model Number: 179 with model MultivariateMotif in generation 1 of 10
# Model Number: 180 with model MultivariateMotif in generation 1 of 10
# Model Number: 181 with model MultivariateMotif in generation 1 of 10
# Model Number: 182 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 182: DatepartRegression
# Model Number: 183 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 183: DatepartRegression
# Model Number: 184 with model DatepartRegression in generation 1 of 10
# Model Number: 185 with model UnivariateMotif in generation 1 of 10
# Model Number: 186 with model UnivariateMotif in generation 1 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 187 with model UnivariateMotif in generation 1 of 10
# Model Number: 188 with model UnivariateMotif in generation 1 of 10
# Model Number: 189 with model GLM in generation 1 of 10
# Model Number: 190 with model GLM in generation 1 of 10
# Model Number: 191 with model GLM in generation 1 of 10
# Model Number: 192 with model GLM in generation 1 of 10
# Model Number: 193 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 193: GluonTS
# Model Number: 194 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 194: GluonTS
# Model Number: 195 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 195: GluonTS
# Model Number: 196 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 196: GluonTS
# Model Number: 197 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 197: VAR
# Model Number: 198 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 198: VAR
# Model Number: 199 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 199: VAR
# Model Number: 200 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 200: VAR
# Model Number: 201 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 201: VECM
# Model Number: 202 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('hpfilter does not handle null values.') in model 202: VECM
# Model Number: 203 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 203: VECM
# Model Number: 204 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 204: VECM
# Model Number: 205 with model FBProphet in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 205: FBProphet
# Model Number: 206 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 206: FBProphet
# Model Number: 207 with model FBProphet in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 207: FBProphet
# Model Number: 208 with model FBProphet in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 208: FBProphet
# Model Number: 209 with model ARDL in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 209: ARDL
# Model Number: 210 with model ARDL in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 210: ARDL
# Model Number: 211 with model ARDL in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 211: ARDL
# Model Number: 212 with model ARDL in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 212: ARDL
# New Generation: 2 of 10
# Model Number: 213 with model NVAR in generation 2 of 10
# Model Number: 214 with model NVAR in generation 2 of 10
# Model Number: 215 with model NVAR in generation 2 of 10
# Model Number: 216 with model NVAR in generation 2 of 10
# Model Number: 217 with model SeasonalNaive in generation 2 of 10
# Model Number: 218 with model SeasonalNaive in generation 2 of 10
# Model Number: 219 with model SeasonalNaive in generation 2 of 10
# Model Number: 220 with model SeasonalNaive in generation 2 of 10
# Model Number: 221 with model ETS in generation 2 of 10
# Model Number: 222 with model ETS in generation 2 of 10
# Model Number: 223 with model ETS in generation 2 of 10
# Model Number: 224 with model ETS in generation 2 of 10
# Model Number: 225 with model LastValueNaive in generation 2 of 10
# Model Number: 226 with model LastValueNaive in generation 2 of 10
# Model Number: 227 with model LastValueNaive in generation 2 of 10
# Model Number: 228 with model ZeroesNaive in generation 2 of 10
# Model Number: 229 with model ZeroesNaive in generation 2 of 10
# Model Number: 230 with model ZeroesNaive in generation 2 of 10
# Model Number: 231 with model AverageValueNaive in generation 2 of 10
# Model Number: 232 with model AverageValueNaive in generation 2 of 10
# Model Number: 233 with model AverageValueNaive in generation 2 of 10
# Model Number: 234 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 234: WindowRegression
# Model Number: 235 with model WindowRegression in generation 2 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 235: WindowRegression
# Model Number: 236 with model WindowRegression in generation 2 of 10
# Model Number: 237 with model GLS in generation 2 of 10
# Model Number: 238 with model GLS in generation 2 of 10
# Model Number: 239 with model SectionalMotif in generation 2 of 10
# Model Number: 240 with model SectionalMotif in generation 2 of 10
# Model Number: 241 with model SectionalMotif in generation 2 of 10
# Model Number: 242 with model SectionalMotif in generation 2 of 10
# Model Number: 243 with model Theta in generation 2 of 10
# Model Number: 244 with model Theta in generation 2 of 10
# Model Number: 245 with model Theta in generation 2 of 10
# Model Number: 246 with model Theta in generation 2 of 10
# Model Number: 247 with model MultivariateMotif in generation 2 of 10
# Model Number: 248 with model MultivariateMotif in generation 2 of 10
# Model Number: 249 with model MultivariateMotif in generation 2 of 10
# Model Number: 250 with model MultivariateMotif in generation 2 of 10
# Model Number: 251 with model UnobservedComponents in generation 2 of 10
# Model Number: 252 with model UnobservedComponents in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 252: UnobservedComponents
# Model Number: 253 with model UnobservedComponents in generation 2 of 10
# Model Number: 254 with model DatepartRegression in generation 2 of 10
# Model Number: 255 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 255: DatepartRegression
# Model Number: 256 with model DatepartRegression in generation 2 of 10
# Model Number: 257 with model UnivariateMotif in generation 2 of 10
# Model Number: 258 with model UnivariateMotif in generation 2 of 10
# Model Number: 259 with model UnivariateMotif in generation 2 of 10
# Model Number: 260 with model UnivariateMotif in generation 2 of 10
# Model Number: 261 with model GLM in generation 2 of 10
# Model Number: 262 with model GLM in generation 2 of 10
# Model Number: 263 with model GLM in generation 2 of 10
# Model Number: 264 with model GLM in generation 2 of 10
# Model Number: 265 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 265: GluonTS
# Model Number: 266 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 266: GluonTS
# Model Number: 267 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 267: GluonTS
# Model Number: 268 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 268: GluonTS
# Model Number: 269 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 269: VAR
# Model Number: 270 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 270: VAR
# Model Number: 271 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 271: VAR
# Model Number: 272 with model VAR in generation 2 of 10
# Template Eval Error: KeyError('aic') in model 272: VAR
# Model Number: 273 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 273: VECM
# Model Number: 274 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 274: VECM
# Model Number: 275 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 275: VECM
# Model Number: 276 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 276: VECM
# Model Number: 277 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 277: FBProphet
# Model Number: 278 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 278: FBProphet
# Model Number: 279 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 279: FBProphet
# Model Number: 280 with model FBProphet in generation 2 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 280: FBProphet
# Model Number: 281 with model ARDL in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 281: ARDL
# Model Number: 282 with model ARDL in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 282: ARDL
# Model Number: 283 with model ARDL in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 283: ARDL
# Model Number: 284 with model ARDL in generation 2 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 284: ARDL
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/scipy/interpolate/polyint.py:545: RuntimeWarning: overflow encountered in multiply
#   self.wi[:j] *= (self.xi[j]-self.xi[:j])
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/scipy/interpolate/polyint.py:546: RuntimeWarning: overflow encountered in reduce
#   self.wi[j] = np.multiply.reduce(self.xi[:j]-self.xi[j])
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/scipy/interpolate/polyint.py:643: RuntimeWarning: invalid value encountered in true_divide
#   p = np.dot(c,self.yi)/np.sum(c,axis=-1)[...,np.newaxis]
# New Generation: 3 of 10
# Model Number: 285 with model NVAR in generation 3 of 10
# Model Number: 286 with model NVAR in generation 3 of 10
# Model Number: 287 with model NVAR in generation 3 of 10
# Model Number: 288 with model NVAR in generation 3 of 10
# Model Number: 289 with model SectionalMotif in generation 3 of 10
# Model Number: 290 with model SectionalMotif in generation 3 of 10
# Model Number: 291 with model SectionalMotif in generation 3 of 10
# Model Number: 292 with model SectionalMotif in generation 3 of 10
# Model Number: 293 with model SeasonalNaive in generation 3 of 10
# Model Number: 294 with model SeasonalNaive in generation 3 of 10
# Model Number: 295 with model SeasonalNaive in generation 3 of 10
# Model Number: 296 with model SeasonalNaive in generation 3 of 10
# Model Number: 297 with model ETS in generation 3 of 10
# Model Number: 298 with model ETS in generation 3 of 10
# Model Number: 299 with model ETS in generation 3 of 10
# Model Number: 300 with model ETS in generation 3 of 10
# Model Number: 301 with model LastValueNaive in generation 3 of 10
# Model Number: 302 with model LastValueNaive in generation 3 of 10
# Model Number: 303 with model ZeroesNaive in generation 3 of 10
# Model Number: 304 with model ZeroesNaive in generation 3 of 10
# Model Number: 305 with model ZeroesNaive in generation 3 of 10
# Model Number: 306 with model AverageValueNaive in generation 3 of 10
# Model Number: 307 with model AverageValueNaive in generation 3 of 10
# Model Number: 308 with model AverageValueNaive in generation 3 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# Model Number: 309 with model WindowRegression in generation 3 of 10
# Model Number: 310 with model WindowRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 310: WindowRegression
# Model Number: 311 with model WindowRegression in generation 3 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 312 with model GLS in generation 3 of 10
# Model Number: 313 with model GLS in generation 3 of 10
# Model Number: 314 with model GLS in generation 3 of 10
# Model Number: 315 with model MultivariateMotif in generation 3 of 10
# Model Number: 316 with model MultivariateMotif in generation 3 of 10
# Model Number: 317 with model MultivariateMotif in generation 3 of 10
# Model Number: 318 with model MultivariateMotif in generation 3 of 10
# Model Number: 319 with model Theta in generation 3 of 10
# Model Number: 320 with model Theta in generation 3 of 10
# Model Number: 321 with model Theta in generation 3 of 10
# Model Number: 322 with model Theta in generation 3 of 10
# Model Number: 323 with model DatepartRegression in generation 3 of 10
# Model Number: 324 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 324: DatepartRegression
# Model Number: 325 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 325: DatepartRegression
# Model Number: 326 with model UnobservedComponents in generation 3 of 10
# Model Number: 327 with model UnobservedComponents in generation 3 of 10
# Model Number: 328 with model UnobservedComponents in generation 3 of 10
# Model Number: 329 with model UnivariateMotif in generation 3 of 10
# Model Number: 330 with model UnivariateMotif in generation 3 of 10
# Model Number: 331 with model UnivariateMotif in generation 3 of 10
# Model Number: 332 with model UnivariateMotif in generation 3 of 10
# Model Number: 333 with model GLM in generation 3 of 10
# Model Number: 334 with model GLM in generation 3 of 10
# Model Number: 335 with model GLM in generation 3 of 10
# Model Number: 336 with model GluonTS in generation 3 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 336: GluonTS
# Model Number: 337 with model GluonTS in generation 3 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 337: GluonTS
# Model Number: 338 with model GluonTS in generation 3 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 338: GluonTS
# Model Number: 339 with model GluonTS in generation 3 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 339: GluonTS
# Model Number: 340 with model VAR in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 340: VAR
# Model Number: 341 with model VAR in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 341: VAR
# Model Number: 342 with model VAR in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 342: VAR
# Model Number: 343 with model VAR in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 343: VAR
# Model Number: 344 with model VECM in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 344: VECM
# Model Number: 345 with model VECM in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 345: VECM
# Model Number: 346 with model VECM in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 346: VECM
# Model Number: 347 with model VECM in generation 3 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 347: VECM
# Model Number: 348 with model FBProphet in generation 3 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 348: FBProphet
# Model Number: 349 with model FBProphet in generation 3 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 349: FBProphet
# Model Number: 350 with model FBProphet in generation 3 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 350: FBProphet
# Model Number: 351 with model FBProphet in generation 3 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 351: FBProphet
# Model Number: 352 with model ARDL in generation 3 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 352: ARDL
# Model Number: 353 with model ARDL in generation 3 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/api.py)") in model 353: ARDL
# Model Number: 354 with model ARDL in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 354: ARDL
# Model Number: 355 with model ARDL in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 355: ARDL
# New Generation: 4 of 10
# Model Number: 356 with model NVAR in generation 4 of 10
# Model Number: 357 with model NVAR in generation 4 of 10
# Model Number: 358 with model NVAR in generation 4 of 10
# Model Number: 359 with model NVAR in generation 4 of 10
# Model Number: 360 with model SectionalMotif in generation 4 of 10
# Model Number: 361 with model SectionalMotif in generation 4 of 10
# Model Number: 362 with model SectionalMotif in generation 4 of 10
# Model Number: 363 with model SectionalMotif in generation 4 of 10
# Model Number: 364 with model SeasonalNaive in generation 4 of 10
# Model Number: 365 with model SeasonalNaive in generation 4 of 10
# Model Number: 366 with model SeasonalNaive in generation 4 of 10
# Model Number: 367 with model SeasonalNaive in generation 4 of 10
# Model Number: 368 with model ETS in generation 4 of 10
# Model Number: 369 with model ETS in generation 4 of 10
# Model Number: 370 with model ETS in generation 4 of 10
# Model Number: 371 with model ETS in generation 4 of 10
# Model Number: 372 with model LastValueNaive in generation 4 of 10
# Model Number: 373 with model LastValueNaive in generation 4 of 10
# Model Number: 374 with model LastValueNaive in generation 4 of 10
# Model Number: 375 with model ZeroesNaive in generation 4 of 10
# Model Number: 376 with model ZeroesNaive in generation 4 of 10
# Model Number: 377 with model ZeroesNaive in generation 4 of 10
# Model Number: 378 with model AverageValueNaive in generation 4 of 10
# Model Number: 379 with model AverageValueNaive in generation 4 of 10
# Model Number: 380 with model AverageValueNaive in generation 4 of 10
# Model Number: 381 with model WindowRegression in generation 4 of 10
# Model Number: 382 with model WindowRegression in generation 4 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 382: WindowRegression
# Model Number: 383 with model WindowRegression in generation 4 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_regression.py:421: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 384 with model GLS in generation 4 of 10
# Model Number: 385 with model GLS in generation 4 of 10
# Model Number: 386 with model MultivariateMotif in generation 4 of 10
# Model Number: 387 with model MultivariateMotif in generation 4 of 10
# Model Number: 388 with model MultivariateMotif in generation 4 of 10
# Model Number: 389 with model MultivariateMotif in generation 4 of 10
# Model Number: 390 with model Theta in generation 4 of 10
# Model Number: 391 with model Theta in generation 4 of 10
# Model Number: 392 with model Theta in generation 4 of 10
# Model Number: 393 with model Theta in generation 4 of 10
# Model Number: 394 with model DatepartRegression in generation 4 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Model Number: 395 with model DatepartRegression in generation 4 of 10
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 396 with model DatepartRegression in generation 4 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 396: DatepartRegression
# Model Number: 397 with model UnobservedComponents in generation 4 of 10
# Model Number: 398 with model UnobservedComponents in generation 4 of 10
# Model Number: 399 with model UnobservedComponents in generation 4 of 10
# Model Number: 400 with model UnivariateMotif in generation 4 of 10
# Model Number: 401 with model UnivariateMotif in generation 4 of 10
# Model Number: 402 with model UnivariateMotif in generation 4 of 10
# Model Number: 403 with model UnivariateMotif in generation 4 of 10
# Model Number: 404 with model GLM in generation 4 of 10
# Model Number: 405 with model GLM in generation 4 of 10
# Model Number: 406 with model GLM in generation 4 of 10
# Model Number: 407 with model GLM in generation 4 of 10
# Model Number: 408 with model GluonTS in generation 4 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 408: GluonTS
# Model Number: 409 with model GluonTS in generation 4 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 409: GluonTS
# Model Number: 410 with model GluonTS in generation 4 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 410: GluonTS
# Model Number: 411 with model GluonTS in generation 4 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 411: GluonTS
# Model Number: 412 with model VAR in generation 4 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 412: VAR
# Model Number: 413 with model VAR in generation 4 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 413: VAR
# ...
# 122 - GLM with avg smape 4.77:
# Model Number: 123 of 125 with model UnivariateMotif for Validation 1
# 123 - UnivariateMotif with avg smape 1.26:
# Model Number: 124 of 125 with model UnivariateMotif for Validation 1
# 124 - UnivariateMotif with avg smape 3.86:
# Model Number: 125 of 125 with model GLM for Validation 1
# 125 - GLM with avg smape 4.93:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:293: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# Validation Round: 2
# Model Number: 1 of 125 with model Ensemble for Validation 2
# 1 - Ensemble with avg smape 2.65:
# Model Number: 2 of 125 with model NVAR for Validation 2
# 2 - NVAR with avg smape 4.41:
# Model Number: 3 of 125 with model NVAR for Validation 2
# 3 - NVAR with avg smape 2.63:
# Model Number: 4 of 125 with model NVAR for Validation 2
# 4 - NVAR with avg smape 1.03:
# Model Number: 5 of 125 with model NVAR for Validation 2
# 5 - NVAR with avg smape 4.8:
# Model Number: 6 of 125 with model NVAR for Validation 2
# 6 - NVAR with avg smape 2.69:
# Model Number: 7 of 125 with model NVAR for Validation 2
# 7 - NVAR with avg smape 2.71:
# Model Number: 8 of 125 with model NVAR for Validation 2
# 8 - NVAR with avg smape 2.71:
# Model Number: 9 of 125 with model NVAR for Validation 2
# 9 - NVAR with avg smape 2.71:
# Model Number: 10 of 125 with model Ensemble for Validation 2
# 10 - Ensemble with avg smape 1.19:
# Model Number: 11 of 125 with model Ensemble for Validation 2
# 11 - Ensemble with avg smape 1.2:
# Model Number: 12 of 125 with model Ensemble for Validation 2
# 12 - Ensemble with avg smape 1.2:
# Model Number: 13 of 125 with model GLS for Validation 2
# 13 - GLS with avg smape 2.19:
# Model Number: 14 of 125 with model GLS for Validation 2
# 14 - GLS with avg smape 2.19:
# Model Number: 15 of 125 with model SectionalMotif for Validation 2
# 15 - SectionalMotif with avg smape 2.2:
# Model Number: 16 of 125 with model GLS for Validation 2
# 16 - GLS with avg smape 2.12:
# Model Number: 17 of 125 with model GLS for Validation 2
# 17 - GLS with avg smape 3.06:
# Model Number: 18 of 125 with model GLS for Validation 2
# 18 - GLS with avg smape 1.84:
# Model Number: 19 of 125 with model SeasonalNaive for Validation 2
# 19 - SeasonalNaive with avg smape 2.03:
# Model Number: 20 of 125 with model SeasonalNaive for Validation 2
# 20 - SeasonalNaive with avg smape 2.08:
# Model Number: 21 of 125 with model SeasonalNaive for Validation 2
# 21 - SeasonalNaive with avg smape 2.08:
# Model Number: 22 of 125 with model SeasonalNaive for Validation 2
# 22 - SeasonalNaive with avg smape 2.22:
# Model Number: 23 of 125 with model MultivariateMotif for Validation 2
# 23 - MultivariateMotif with avg smape 1.9:
# Model Number: 24 of 125 with model SeasonalNaive for Validation 2
# 24 - SeasonalNaive with avg smape 1.71:
# Model Number: 25 of 125 with model ETS for Validation 2
# 25 - ETS with avg smape 1.57:
# Model Number: 26 of 125 with model ETS for Validation 2
# 26 - ETS with avg smape 1.71:
# Model Number: 27 of 125 with model ETS for Validation 2
# 27 - ETS with avg smape 1.57:
# Model Number: 28 of 125 with model ETS for Validation 2
# 28 - ETS with avg smape 1.57:
# Model Number: 29 of 125 with model LastValueNaive for Validation 2
# 29 - LastValueNaive with avg smape 2.09:
# Model Number: 30 of 125 with model WindowRegression for Validation 2
# 30 - WindowRegression with avg smape 1.21:
# Model Number: 31 of 125 with model LastValueNaive for Validation 2
# 31 - LastValueNaive with avg smape 2.22:
# Model Number: 32 of 125 with model ETS for Validation 2
# 32 - ETS with avg smape 1.57:
# Model Number: 33 of 125 with model UnobservedComponents for Validation 2
# 33 - UnobservedComponents with avg smape 1.44:
# Model Number: 34 of 125 with model LastValueNaive for Validation 2
# 34 - LastValueNaive with avg smape 2.1:
# Model Number: 35 of 125 with model LastValueNaive for Validation 2
# 35 - LastValueNaive with avg smape 2.1:
# Model Number: 36 of 125 with model SeasonalNaive for Validation 2
# 36 - SeasonalNaive with avg smape 2.26:
# Model Number: 37 of 125 with model SeasonalNaive for Validation 2
# 37 - SeasonalNaive with avg smape 2.35:
# Model Number: 38 of 125 with model SeasonalNaive for Validation 2
# 38 - SeasonalNaive with avg smape 2.25:
# Model Number: 39 of 125 with model LastValueNaive for Validation 2
# 39 - LastValueNaive with avg smape 2.07:
# Model Number: 40 of 125 with model LastValueNaive for Validation 2
# 40 - LastValueNaive with avg smape 2.27:
# Model Number: 41 of 125 with model LastValueNaive for Validation 2
# 41 - LastValueNaive with avg smape 2.07:
# Model Number: 42 of 125 with model ETS for Validation 2
# 42 - ETS with avg smape 1.34:
# Model Number: 43 of 125 with model ETS for Validation 2
# 43 - ETS with avg smape 1.57:
# Model Number: 44 of 125 with model ETS for Validation 2
# 44 - ETS with avg smape 1.57:
# Model Number: 45 of 125 with model LastValueNaive for Validation 2
# 45 - LastValueNaive with avg smape 2.31:
# Model Number: 46 of 125 with model ZeroesNaive for Validation 2
# 46 - ZeroesNaive with avg smape 2.03:
# Model Number: 47 of 125 with model SectionalMotif for Validation 2
# 47 - SectionalMotif with avg smape 3.14:
# Model Number: 48 of 125 with model Ensemble for Validation 2
# 48 - Ensemble with avg smape 2.69:
# Model Number: 49 of 125 with model MultivariateMotif for Validation 2
# 49 - MultivariateMotif with avg smape 1.41:
# Model Number: 50 of 125 with model WindowRegression for Validation 2
# 50 - WindowRegression with avg smape 1.74:
# Model Number: 51 of 125 with model AverageValueNaive for Validation 2
# 51 - AverageValueNaive with avg smape 3.41:
# Model Number: 52 of 125 with model Theta for Validation 2
# 52 - Theta with avg smape 2.78:
# Model Number: 53 of 125 with model MultivariateMotif for Validation 2
# 53 - MultivariateMotif with avg smape 1.85:
# Model Number: 54 of 125 with model SectionalMotif for Validation 2
# 54 - SectionalMotif with avg smape 6.68:
# Model Number: 55 of 125 with model AverageValueNaive for Validation 2
# 55 - AverageValueNaive with avg smape 5.19:
# Model Number: 56 of 125 with model AverageValueNaive for Validation 2
# 56 - AverageValueNaive with avg smape 5.19:
# Model Number: 57 of 125 with model MultivariateMotif for Validation 2
# Template Eval Error: ValueError('kth(=15) out of bounds (15)') in model 57: MultivariateMotif
# Model Number: 58 of 125 with model MultivariateMotif for Validation 2
# Template Eval Error: ValueError('kth(=10) out of bounds (10)') in model 58: MultivariateMotif
# Model Number: 59 of 125 with model WindowRegression for Validation 2
# 59 - WindowRegression with avg smape 1.28:
# Model Number: 60 of 125 with model ZeroesNaive for Validation 2
# 60 - ZeroesNaive with avg smape 1.83:
# Model Number: 61 of 125 with model AverageValueNaive for Validation 2
# 61 - AverageValueNaive with avg smape 3.04:
# Model Number: 62 of 125 with model ZeroesNaive for Validation 2
# 62 - ZeroesNaive with avg smape 1.82:
# Model Number: 63 of 125 with model GLS for Validation 2
# 63 - GLS with avg smape 2.52:
# Model Number: 64 of 125 with model SectionalMotif for Validation 2
# 64 - SectionalMotif with avg smape 5.28:
# Model Number: 65 of 125 with model DatepartRegression for Validation 2
# 65 - DatepartRegression with avg smape 1.75:
# Model Number: 66 of 125 with model AverageValueNaive for Validation 2
# 66 - AverageValueNaive with avg smape 5.47:
# Model Number: 67 of 125 with model AverageValueNaive for Validation 2
# 67 - AverageValueNaive with avg smape 5.47:
# Model Number: 68 of 125 with model GLM for Validation 2
# 68 - GLM with avg smape 4.04:
# Model Number: 69 of 125 with model MultivariateMotif for Validation 2
# 69 - MultivariateMotif with avg smape 1.81:
# Model Number: 70 of 125 with model SectionalMotif for Validation 2
# 70 - SectionalMotif with avg smape 2.84:
# Model Number: 71 of 125 with model AverageValueNaive for Validation 2
# 71 - AverageValueNaive with avg smape 5.59:
# Model Number: 72 of 125 with model UnobservedComponents for Validation 2
# 72 - UnobservedComponents with avg smape 1.54:
# Model Number: 73 of 125 with model ZeroesNaive for Validation 2
# 73 - ZeroesNaive with avg smape 2.76:
# Model Number: 74 of 125 with model SectionalMotif for Validation 2
# 74 - SectionalMotif with avg smape 2.45:
# Model Number: 75 of 125 with model MultivariateMotif for Validation 2
# 75 - MultivariateMotif with avg smape 1.49:
# Model Number: 76 of 125 with model Theta for Validation 2
# 76 - Theta with avg smape 2.36:
# Model Number: 77 of 125 with model Theta for Validation 2
# 77 - Theta with avg smape 1.81:
# Model Number: 78 of 125 with model GLS for Validation 2
# 78 - GLS with avg smape 2.33:
# Model Number: 79 of 125 with model SectionalMotif for Validation 2
# 79 - SectionalMotif with avg smape 2.13:
# Model Number: 80 of 125 with model Theta for Validation 2
# 80 - Theta with avg smape 2.01:
# Model Number: 81 of 125 with model DatepartRegression for Validation 2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 81 - DatepartRegression with avg smape 2.81:
# Model Number: 82 of 125 with model MultivariateMotif for Validation 2
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 82 - MultivariateMotif with avg smape 2.79:
# Model Number: 83 of 125 with model DatepartRegression for Validation 2
# 83 - DatepartRegression with avg smape 2.45:
# Model Number: 84 of 125 with model Theta for Validation 2
# 84 - Theta with avg smape 2.02:
# Model Number: 85 of 125 with model UnobservedComponents for Validation 2
# 85 - UnobservedComponents with avg smape 1.72:
# Model Number: 86 of 125 with model Theta for Validation 2
# 86 - Theta with avg smape 2.0:
# Model Number: 87 of 125 with model ZeroesNaive for Validation 2
# 87 - ZeroesNaive with avg smape 2.29:
# Model Number: 88 of 125 with model ZeroesNaive for Validation 2
# 88 - ZeroesNaive with avg smape 200.0:
# Model Number: 89 of 125 with model Theta for Validation 2
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:3179: RuntimeWarning: divide by zero encountered in power
#   x_inv[pos] = np.power(x[pos] * lmbda + 1, 1 / lmbda) - 1
# 89 - Theta with avg smape 2.01:
# Model Number: 90 of 125 with model GLS for Validation 2
# 90 - GLS with avg smape 2.94:
# Model Number: 91 of 125 with model WindowRegression for Validation 2
# 91 - WindowRegression with avg smape 2.36:
# Model Number: 92 of 125 with model DatepartRegression for Validation 2
# 92 - DatepartRegression with avg smape 2.07:
# Model Number: 93 of 125 with model UnobservedComponents for Validation 2
# 93 - UnobservedComponents with avg smape 1.81:
# Model Number: 94 of 125 with model SectionalMotif for Validation 2
# 94 - SectionalMotif with avg smape 5.76:
# Model Number: 95 of 125 with model Theta for Validation 2
# 95 - Theta with avg smape 1.74:
# Model Number: 96 of 125 with model DatepartRegression for Validation 2
# 96 - DatepartRegression with avg smape 1.56:
# Model Number: 97 of 125 with model WindowRegression for Validation 2
# 97 - WindowRegression with avg smape 1.85:
# Model Number: 98 of 125 with model UnobservedComponents for Validation 2
# 98 - UnobservedComponents with avg smape 2.14:
# Model Number: 99 of 125 with model WindowRegression for Validation 2
# 99 - WindowRegression with avg smape 1.76:
# Model Number: 100 of 125 with model UnobservedComponents for Validation 2
# 100 - UnobservedComponents with avg smape 1.88:
# Model Number: 101 of 125 with model UnobservedComponents for Validation 2
# 101 - UnobservedComponents with avg smape 1.68:
# Model Number: 102 of 125 with model UnobservedComponents for Validation 2
# 102 - UnobservedComponents with avg smape 1.33:
# Model Number: 103 of 125 with model WindowRegression for Validation 2
# 103 - WindowRegression with avg smape 1.93:
# Model Number: 104 of 125 with model ZeroesNaive for Validation 2
# 104 - ZeroesNaive with avg smape 2.09:
# Model Number: 105 of 125 with model AverageValueNaive for Validation 2
# 105 - AverageValueNaive with avg smape 1.82:
# Model Number: 106 of 125 with model GLM for Validation 2
# 106 - GLM with avg smape 2.0:
# Model Number: 107 of 125 with model DatepartRegression for Validation 2
# 107 - DatepartRegression with avg smape 11.63:
# Model Number: 108 of 125 with model WindowRegression for Validation 2
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 108 - WindowRegression with avg smape 1.62:
# Model Number: 109 of 125 with model DatepartRegression for Validation 2
# 109 - DatepartRegression with avg smape 1.81:
# Model Number: 110 of 125 with model UnivariateMotif for Validation 2
# 110 - UnivariateMotif with avg smape 2.75:
# Model Number: 111 of 125 with model UnivariateMotif for Validation 2
# 111 - UnivariateMotif with avg smape 5.17:
# Model Number: 112 of 125 with model DatepartRegression for Validation 2
# 112 - DatepartRegression with avg smape 2.53:
# Model Number: 113 of 125 with model ZeroesNaive for Validation 2
# 113 - ZeroesNaive with avg smape 4.03:
# Model Number: 114 of 125 with model GLM for Validation 2
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 114 - GLM with avg smape 2.01:
# Model Number: 115 of 125 with model GLM for Validation 2
# 115 - GLM with avg smape 2.03:
# Model Number: 116 of 125 with model UnivariateMotif for Validation 2
# 116 - UnivariateMotif with avg smape 2.37:
# Model Number: 117 of 125 with model UnivariateMotif for Validation 2
# 117 - UnivariateMotif with avg smape 5.52:
# Model Number: 118 of 125 with model UnivariateMotif for Validation 2
# 118 - UnivariateMotif with avg smape 2.56:
# Model Number: 119 of 125 with model GLM for Validation 2
# 119 - GLM with avg smape 10.92:
# Model Number: 120 of 125 with model UnivariateMotif for Validation 2
# 120 - UnivariateMotif with avg smape 4.51:
# Model Number: 121 of 125 with model GLM for Validation 2
# 121 - GLM with avg smape 8.62:
# Model Number: 122 of 125 with model GLM for Validation 2
# 122 - GLM with avg smape 8.55:
# Model Number: 123 of 125 with model UnivariateMotif for Validation 2
# 123 - UnivariateMotif with avg smape 3.95:
# Model Number: 124 of 125 with model UnivariateMotif for Validation 2
# 124 - UnivariateMotif with avg smape 1.95:
# Model Number: 125 of 125 with model GLM for Validation 2
# 125 - GLM with avg smape 8.69:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:293: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "

# %%
prediction = model.predict()
forecast = prediction.forecast

# %%
print('Nifty Predection for Next 10 Days')
print(forecast)
# Out:
# Nifty Predection for Next 10 Days
#                    Close
# 2021-12-24  16909.560070
# 2021-12-27  16846.178851
# 2021-12-28  16827.886519
# 2021-12-29  16801.418443
# 2021-12-30  16789.403658
# 2021-12-31  16783.135339
# 2022-01-03  16743.009482
# 2022-01-04  16728.331481
# 2022-01-05  16694.037488
# 2022-01-06  16679.966899

# %%
plt.plot(forecast['Close'])
